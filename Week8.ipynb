# %% [markdown]
# <a href="https://colab.research.google.com/github/mdailey034-design/CSC121-Spring2026-Assignments/blob/main/Week8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS

# FUNCTION DEFINITIONS
def is_palindrome(word):
  """
  Checks if a given word is a palindrome (reads the same forwards and backwards).

  Args:
    word: The string to be checked.

  Returns:
    True if the word is a palindrome, False otherwise.
  """
  # Convert the word to lowercase to handle case-insensitivity
  cleaned_word = str(word).lower()
  # Compare the cleaned word with its reverse
  return cleaned_word == cleaned_word[::-1]

# Example usage:
print(f"'madam' is a palindrome: {is_palindrome('madam')}")
print(f"'racecar' is a palindrome: {is_palindrome('racecar')}")
print(f"'hello' is a palindrome: {is_palindrome('hello')}")
print(f"'level' is a palindrome: {is_palindrome('level')}")
print(f"'AmoMA' is a palindrome: {is_palindrome('AmoMA')}")

# PROGRAM LOGIC
user_word = input("Enter a word to check if it's a palindrome: ")

if is_palindrome(user_word):
  print(f"'{user_word}' is a palindrome!")
else:
  print(f"'{user_word}' is not a palindrome.")
# Out:
# 'madam' is a palindrome: True
# 'racecar' is a palindrome: True
# 'hello' is a palindrome: False
# 'level' is a palindrome: True
# 'AmoMA' is a palindrome: True
# Enter a word to check if it's a palindrome: racecar
# 'racecar' is a palindrome!
