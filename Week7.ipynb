# %% [markdown]
# <a href="https://colab.research.google.com/github/mdailey034-design/CSC121-Spring2026-Assignments/blob/main/Week7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time

# FUNCTION DEFINITIONS
def verify_pin():
    while True:
        pin = input("Enter your PIN: ")
        if pin == "1234":
            print("PIN verified successfully!")
            return True
        else:
            print("Incorrect PIN. Please try again.")

def withdraw(balance, amount):
    if amount > 0 and amount <= balance:
        print(f"Withdrawing ${amount:.2f}.")
        time.sleep(1)
        print("Transaction successful.")
        return balance - amount
    elif amount <= 0:
        print("Withdrawal amount must be positive.")
        return balance
    else:
        print("Insufficient funds.")
        return balance

# PROGRAM LOGIC
current_balance = 500
print(f"Current balance: ${current_balance:.2f}")
verify_pin()
# Out:
# Current balance: $500.00
# Enter your PIN: 1234
# PIN verified successfully!
# True
