# %% [markdown]
# <a href="https://colab.research.google.com/github/mdailey034-design/CSC121-Spring2026-Assignments/blob/main/Week14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: library.py
# IMPORT STATEMENTS
# The Book Class: Create a class named Book.

# The Initialization (__init__): * The class must have an __init__ method that accepts title and author.

# It should also include a third attribute, is_available, which defaults to True.

# The String Representation (__str__): * Use the special __str__ method so that when a book object is printed, it returns a user-friendly string (e.g., "The Great Gatsby by F. Scott Fitzgerald - Available").


# CLASS DEFINITIONS
# Class Methods: * Create a method called checkout() that sets is_available to False.

# Create a method called return_book() that sets is_available to True.

# PROGRAM LOGIC
# Create at least two separate instances (objects) of the Book class.

# Print the status of both books.

# "Check out" one of the books using your method.

# Print both books again to show that the status of the specific object has changed.
