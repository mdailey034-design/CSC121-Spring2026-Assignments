# %% [markdown]
# <a href="https://colab.research.google.com/github/mdailey034-design/CSC121-Spring2026-Assignments/blob/main/Week14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Book:
    def __init__(self, title, author):
        self.title = title
        self.author = author
        self.is_available = True

# PROGRAM LOGIC
# Create at least two separate instances (objects) of the Book class.
# For now, let's just create one to test the __init__ method.
my_book = Book("The Great Gatsby", "F. Scott Fitzgerald")

# Print one of its attributes to make sure the object is being built correctly.
print(f"Book Title: {my_book.title}")
print(f"Book Author: {my_book.author}")
print(f"Is Available: {my_book.is_available}")

# Print the status of both books.

# "Check out" one of the books using your method.

# Print both books again to show that the status of the specific object has changed.
# Out:
# Book Title: The Great Gatsby
# Book Author: F. Scott Fitzgerald
# Is Available: True
